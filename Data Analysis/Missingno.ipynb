# %%
import pandas as pd
import missingno as msno

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Diabete.xlsx')

# %%
msno.matrix(data)

plt.show()

# %%
import seaborn as sns

# stesso grafico ma visivamente più piacevole
sns.heatmap(data.isnull(), cmap='viridis')

plt.show()
