# %%
# !python IperparametersOptimization.py
# Out:
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# Accuracy: 0.97
# Precision: 0.93
# Recall: 0.69
# F1-Score: 0.79
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.97
# Precision: 0.94
# Recall: 0.68
# F1-Score: 0.79
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.97
# Precision: 0.94
# Recall: 0.68
# F1-Score: 0.79
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Accuracy: 0.97
# Precision: 0.95
# Recall: 0.69
# F1-Score: 0.80
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.97
# Precision: 0.97
# Recall: 0.68
# F1-Score: 0.80
# --------------
# ...
