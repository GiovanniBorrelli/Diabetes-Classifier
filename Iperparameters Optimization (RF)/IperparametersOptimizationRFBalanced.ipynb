# %%
# !python DiabetesBLRFPredictor.py
# Out:
# Classificatore 1:
# Accuracy: 0.94
# Precision: 0.97
# Recall: 0.90
# F1-Score: 0.93

# %%
# !python IperparametersOptimization.py
# Out:
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
# Accuracy: 0.93
# Precision: 0.97
# Recall: 0.89
# F1-Score: 0.92
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.94
# Precision: 0.97
# Recall: 0.91
# F1-Score: 0.93
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Accuracy: 0.93
# Precision: 0.96
# Recall: 0.90
# F1-Score: 0.92
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.94
# Precision: 0.97
# Recall: 0.90
# F1-Score: 0.93
# --------------
# Iperparametri: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# Accuracy: 0.93
# Precision: 0.96
# Recall: 0.90
# F1-Score: 0.92
# --------------
# ...
